# %%
import pandas as pd
from nba_api.stats.endpoints import commonteamroster, leaguestandings
from nba_api.stats.static import teams
import time
from datetime import datetime

def get_season_string(year):
    """Convert year to NBA season string format (e.g., 2000 -> '2000-01')"""
    return f"{year}-{str(year + 1)[-2:]}"

def get_all_stars_by_season(season):
    """Get All-Stars for a given season (simplified - would need manual data or API)"""
    # Note: nba_api doesn't have direct All-Star roster endpoint
    # You would need to supplement this with external data or manual collection
    # This is a placeholder that returns empty set
    return set()

def get_team_roster(team_id, season):
    """Get roster for a specific team and season"""
    try:
        roster = commonteamroster.CommonTeamRoster(
            team_id=team_id,
            season=season
        )
        time.sleep(0.6)  # Rate limiting
        return roster.get_data_frames()[0]
    except Exception as e:
        print(f"Error fetching roster for team {team_id} in {season}: {e}")
        return pd.DataFrame()

def calculate_roster_metrics(current_roster, previous_roster, all_stars_set):
    """Calculate various roster construction metrics"""
    if current_roster.empty:
        return None
    
    # Get player IDs
    current_players = set(current_roster['PLAYER_ID'].values)
    previous_players = set(previous_roster['PLAYER_ID'].values) if not previous_roster.empty else set()
    
    # Continuity metrics
    retained_players = len(current_players.intersection(previous_players))
    new_players = len(current_players - previous_players)
    departed_players = len(previous_players - current_players)
    
    # Calculate continuity percentage
    continuity_pct = (retained_players / len(previous_players) * 100) if len(previous_players) > 0 else 0
    
    # Age metrics
    ages = pd.to_numeric(current_roster['AGE'], errors='coerce')
    avg_age = ages.mean()
    median_age = ages.median()
    oldest_player = ages.max()
    youngest_player = ages.min()
    
    # All-Star count
    all_star_count = len(current_players.intersection(all_stars_set))
    
    # Roster size
    roster_size = len(current_players)
    
    # Experience metrics (if available in roster data)
    if 'EXP' in current_roster.columns:
        exp_values = pd.to_numeric(current_roster['EXP'].replace('R', '0'), errors='coerce')
        avg_experience = exp_values.mean()
        rookies_count = (current_roster['EXP'] == 'R').sum()
    else:
        avg_experience = None
        rookies_count = None
    
    return {
        'roster_size': roster_size,
        'retained_players': retained_players,
        'new_players': new_players,
        'departed_players': departed_players,
        'continuity_pct': continuity_pct,
        'avg_age': avg_age,
        'median_age': median_age,
        'oldest_player': oldest_player,
        'youngest_player': youngest_player,
        'all_star_count': all_star_count,
        'avg_experience': avg_experience,
        'rookies_count': rookies_count
    }

def collect_roster_construction_data(start_year=2000, end_year=None):
    """
    Collect roster construction data for all teams from start_year to end_year
    
    Args:
        start_year: Starting year (default 2000 for 2000-01 season)
        end_year: Ending year (default current year)
    """
    if end_year is None:
        end_year = datetime.now().year
    
    # Get all NBA teams
    all_teams = teams.get_teams()
    
    # Storage for results
    all_data = []
    
    # Storage for previous season rosters
    previous_rosters = {}
    
    print(f"Collecting data from {start_year}-{start_year+1} to {end_year}-{end_year+1}")
    print(f"Total teams: {len(all_teams)}")
    print("-" * 60)
    
    for year in range(start_year, end_year + 1):
        season = get_season_string(year)
        print(f"\nProcessing season: {season}")
        
        # Get All-Stars for this season (placeholder)
        all_stars_set = get_all_stars_by_season(season)
        
        for team in all_teams:
            team_id = team['id']
            team_name = team['full_name']
            
            print(f"  Fetching {team_name}...", end=" ")
            
            # Get current season roster
            current_roster = get_team_roster(team_id, season)
            
            if current_roster.empty:
                print("No data")
                continue
            
            # Get previous season roster for continuity calculations
            previous_season = get_season_string(year - 1) if year > start_year else None
            previous_roster = previous_rosters.get((team_id, previous_season), pd.DataFrame())
            
            # Calculate metrics
            metrics = calculate_roster_metrics(current_roster, previous_roster, all_stars_set)
            
            if metrics:
                metrics.update({
                    'season': season,
                    'team_id': team_id,
                    'team_name': team_name
                })
                all_data.append(metrics)
                print("✓")
            else:
                print("Failed")
            
            # Store current roster for next year's continuity calculation
            previous_rosters[(team_id, season)] = current_roster
    
    # Convert to DataFrame
    df = pd.DataFrame(all_data)
    
    # Reorder columns for better readability
    column_order = [
        'season', 'team_name', 'team_id', 'roster_size',
        'retained_players', 'new_players', 'departed_players', 'continuity_pct',
        'avg_age', 'median_age', 'oldest_player', 'youngest_player',
        'all_star_count', 'avg_experience', 'rookies_count'
    ]
    
    df = df[column_order]
    
    return df

# Main execution
if __name__ == "__main__":
    print("Starting NBA Roster Construction Data Collection")
    print("=" * 60)
    
    # Collect data
    roster_data = collect_roster_construction_data(start_year=2000, end_year=2024)
    
    # Save to CSV
    output_file = 'nba_roster_construction_2000_2024.csv'
    roster_data.to_csv(output_file, index=False)
    print(f"\n{'=' * 60}")
    print(f"Data collection complete!")
    print(f"Total records: {len(roster_data)}")
    print(f"Saved to: {output_file}")
    
    # Display summary statistics
    print("\nSummary Statistics:")
    print(roster_data.describe())
    
    # Display sample data
    print("\nSample data (first 5 rows):")
    print(roster_data.head())
# Out:
# Starting NBA Roster Construction Data Collection
# ============================================================
# Collecting data from 2000-2001 to 2024-2025
# Total teams: 30
# ------------------------------------------------------------
#
# Processing season: 2000-01
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... No data
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2001-02
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... No data
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2002-03
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... No data
#
# Processing season: 2003-04
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... No data
#
# Processing season: 2004-05
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2005-06
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2006-07
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2007-08
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2008-09
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2009-10
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2010-11
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2011-12
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2012-13
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2013-14
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2014-15
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2015-16
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2016-17
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2017-18
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2018-19
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2019-20
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... ✓
#   Fetching New Orleans Pelicans... ✓
#   Fetching Chicago Bulls... ✓
#   Fetching Dallas Mavericks... ✓
#   Fetching Denver Nuggets... ✓
#   Fetching Golden State Warriors... ✓
#   Fetching Houston Rockets... ✓
#   Fetching Los Angeles Clippers... ✓
#   Fetching Los Angeles Lakers... ✓
#   Fetching Miami Heat... ✓
#   Fetching Milwaukee Bucks... ✓
#   Fetching Minnesota Timberwolves... ✓
#   Fetching Brooklyn Nets... ✓
#   Fetching New York Knicks... ✓
#   Fetching Orlando Magic... ✓
#   Fetching Indiana Pacers... ✓
#   Fetching Philadelphia 76ers... ✓
#   Fetching Phoenix Suns... ✓
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# Processing season: 2020-21
#   Fetching Atlanta Hawks... ✓
#   Fetching Boston Celtics... ✓
#   Fetching Cleveland Cavaliers... Error fetching roster for team 1610612739 in 2020-21: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# No data
#   Fetching New Orleans Pelicans... Error fetching roster for team 1610612740 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Chicago Bulls... Error fetching roster for team 1610612741 in 2020-21: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# No data
#   Fetching Dallas Mavericks... Error fetching roster for team 1610612742 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Denver Nuggets... Error fetching roster for team 1610612743 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Golden State Warriors... Error fetching roster for team 1610612744 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Houston Rockets... Error fetching roster for team 1610612745 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Los Angeles Clippers... Error fetching roster for team 1610612746 in 2020-21: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# No data
#   Fetching Los Angeles Lakers... Error fetching roster for team 1610612747 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Miami Heat... Error fetching roster for team 1610612748 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Milwaukee Bucks... Error fetching roster for team 1610612749 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching Minnesota Timberwolves... Error fetching roster for team 1610612750 in 2020-21: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No data
#   Fetching
#   Fetching Portland Trail Blazers... ✓
#   Fetching Sacramento Kings... ✓
#   Fetching San Antonio Spurs... ✓
#   Fetching Oklahoma City Thunder... ✓
#   Fetching Toronto Raptors... ✓
#   Fetching Utah Jazz... ✓
#   Fetching Memphis Grizzlies... ✓
#   Fetching Washington Wizards... ✓
#   Fetching Detroit Pistons... ✓
#   Fetching Charlotte Hornets... ✓
#
# ============================================================
# Data collection complete!
# Total records: 650
# Saved to: nba_roster_construction_2000_2024.csv
#
# Summary Statistics:
#             team_id  roster_size  retained_players  new_players  \
# count  6.500000e+02   650.000000        650.000000   650.000000
# mean   1.610613e+09    14.952308          6.712308     8.240000
# std    8.612351e+00     1.666086          3.031220     3.253672
# min    1.610613e+09    11.000000          0.000000     1.000000
# 25%    1.610613e+09    14.000000          5.000000     6.000000
# 50%    1.610613e+09    15.000000          7.000000     8.000000
# 75%    1.610613e+09    16.000000          9.000000    10.000000
# max    1.610613e+09    21.000000         14.000000    18.000000
#
#        departed_players  continuity_pct     avg_age  median_age  \
# count        650.000000      650.000000  650.000000  650.000000
# mean           6.612308       45.938070   26.907083   26.453077
# std            3.208305       20.877261    1.542109    1.882864
# min            0.000000        0.000000   23.500000   22.500000
# 25%            5.000000       35.714286   25.800000   25.000000
# 50%            7.000000       46.666667   26.719608   26.000000
# 75%            9.000000       60.000000   27.866667   28.000000
# max           16.000000       92.857143   32.500000   33.000000
#
#        oldest_player  youngest_player  all_star_count  avg_experience  \
# count     650.000000       650.000000           650.0      650.000000
# mean       34.869231        21.000000             0.0        4.601380
# std         2.863049         1.276793             0.0        1.380744
# min        27.000000        18.000000             0.0        1.166667
# 25%        33.000000        20.000000             0.0        3.600000
# 50%        35.000000        21.000000             0.0        4.440972
# 75%        37.000000        22.000000             0.0        5.408824
# max        44.000000        27.000000             0.0        9.066667
#
#        rookies_count
# count     650.000000
# mean        2.466154
# std         1.442133
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000
#
# Sample data (first 5 rows):
#     season            team_name     team_id  roster_size  retained_players  \
# 0  2000-01        Atlanta Hawks  1610612737           12                 0
# 1  2000-01       Boston Celtics  1610612738           12                 0
# 2  2000-01  Cleveland Cavaliers  1610612739           12                 0
# 3  2000-01        Chicago Bulls  1610612741           12                 0
# 4  2000-01     Dallas Mavericks  1610612742           13                 0
#
#    new_players  departed_players  continuity_pct    avg_age  median_age  \
# 0           12                 0             0.0  25.166667        24.5
# 1           12                 0             0.0  25.416667        25.0
# 2           12                 0             0.0  27.500000        27.0
# 3           12                 0             0.0  23.750000        23.0
# 4           13                 0             0.0  26.923077        27.0
#
#    oldest_player  youngest_player  all_star_count  avg_experience  \
# 0           32.0             21.0               0        2.583333
# 1           30.0             23.0               0        2.750000
# 2           33.0             21.0               0        4.750000
# 3           28.0             20.0               0        1.166667
# 4           36.0             20.0               0        4.307692
#
#    rookies_count
# 0              2
# 1              2
# 2              1
# 3              6
# 4              3
